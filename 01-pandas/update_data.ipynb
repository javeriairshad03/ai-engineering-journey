# %% [markdown]
# ### **UPDATING DATA**
# - modifying data / updating data
# - handling missing data

# %%
import pandas as pd

data = {
    "Name": ["Sara", "Ali", "Irfan", "Usman", "Umer", "Javeria", "Wajeeha", "Bushra"],
    "Age": [18, 19, 28, 40, 30, 32, 29, 25],
    "Salary": [50000, 60000, 23000, 60000, 45000, 62000, 40000, 53000],
    "Performance_score": [80, 90, 78, 82, 88, 92, 89, 77]
}

df1 = pd.DataFrame(data)
print(df1)
print()

# this is how we add a new column , for eg. adding a new column 'Bonus' --- 10% increement in employee's salary
df1["Bonus"] = df1["Salary"] * 0.1
print(df1)
# Out:
#       Name  Age  Salary  Performance_score
# 0     Sara   18   50000                 80
# 1      Ali   19   60000                 90
# 2    Irfan   28   23000                 78
# 3    Usman   40   60000                 82
# 4     Umer   30   45000                 88
# 5  Javeria   32   62000                 92
# 6  Wajeeha   29   40000                 89
# 7   Bushra   25   53000                 77
#
#       Name  Age  Salary  Performance_score   Bonus
# 0     Sara   18   50000                 80  5000.0
# 1      Ali   19   60000                 90  6000.0
# 2    Irfan   28   23000                 78  2300.0
# 3    Usman   40   60000                 82  6000.0
# 4     Umer   30   45000                 88  4500.0
# 5  Javeria   32   62000                 92  6200.0
# 6  Wajeeha   29   40000                 89  4000.0
# 7   Bushra   25   53000                 77  5300.0

# %%
df = pd.read_csv('orders.csv')
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.loc[df["CustomerName"] == "Zara Ahmed"]

df.loc[df["CustomerName"] == "Zara Ahmed", "Product"] = "Electronics"

df.loc[df["CustomerName"] == "Zara Ahmed"]
# Out:
#     OrderID CustomerName      Product    Category  Quantity  Price  \
# 23     1024   Zara Ahmed  Electronics  Stationery        15    4.0
#
#      OrderDate Shipped   Country
# 23  2024-06-25      No  Pakistan

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.loc[df["Country"] == "USA", "Country"] = "United States"

# %%
df.loc[df["Country"] == "United States"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped        Country
# 0   2024-06-01     Yes  United States
# 17  2024-06-19      No  United States
# 33  2024-07-05     Yes  United States

# %%
upper_country = df["Country"].str.upper()
print(upper_country)
# Out:
# 0     UNITED STATES
# 1            CANADA
# 2               UAE
# 3         SINGAPORE
# 4            MEXICO
# 5               UAE
# 6                UK
# 7       SOUTH KOREA
# 8             ITALY
# 9             JAPAN
# 10           FRANCE
# 11            INDIA
# 12        AUSTRALIA
# 13            SPAIN
# 14            CHINA
# 15            EGYPT
# 16           POLAND
# 17    UNITED STATES
# 18            JAPAN
# 19     SAUDI ARABIA
# 20           CANADA
# 21           BRAZIL
# 22          GERMANY
# 23         PAKISTAN
# 24           SWEDEN
# 25           FRANCE
# 26        ARGENTINA
# 27           RUSSIA
# 28      SOUTH KOREA
# 29            ITALY
# 30          MOROCCO
# 31          GERMANY
# 32         COLOMBIA
# 33    UNITED STATES
# 34            JAPAN
# 35               UK
# 36         PORTUGAL
# 37             IRAN
# 38      SOUTH KOREA
# 39          UKRAINE
# Name: Country, dtype: str

# %%
# this is how you save the file copy, and inorder to make it index-free we do it false.
output = df.to_csv("sample_output.csv", index=False)
