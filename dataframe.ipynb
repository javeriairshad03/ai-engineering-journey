# %%
# syntax to import library, and load CSV file
import pandas as pd

df = pd.read_csv('orders.csv')
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
# shows the starting 5 rows, just to show how the Dataframe looks like
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
# shows the last 5 rows, just to show how the Dataframe looks like
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
# this gives a basic overview about our data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
# gives descriptive statistics, like mean, median, mode, std deviation, variation, etc
df.describe()
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
# about index, and accessing
df.index

# to glance at the Columns
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
# df.Country or df["Country"] ---> same result, but one is accessing 'with method' and second is 'with index'
df.Country

df["Country"]
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: str

# %%
len(df["Country"])
# set(df["Country"])
# Out:
# 40

# %%
# syntax for viewing only more than one column or desired columns
df[["Country", "Product", "Price"]]
# Out:
#          Country                Product   Price
# 0            USA                 Laptop  1200.0
# 1         Canada             Headphones   150.0
# 2            UAE           Office Chair   300.0
# 3      Singapore              Desk Lamp    45.0
# 4         Mexico               Keyboard    80.0
# 5            UAE               Notebook     5.0
# 6             UK          Standing Desk   450.0
# 7    South Korea                Monitor   220.0
# 8          Italy                    Pen     1.5
# 9          Japan                  Mouse    35.0
# 10        France                 Webcam    85.0
# 11         India           File Cabinet   180.0
# 12     Australia                Stapler    12.0
# 13         Spain              USB Drive    25.0
# 14         China              Bookshelf   280.0
# 15         Egypt          Printer Paper     8.0
# 16        Poland         Wireless Mouse    45.0
# 17           USA         Desk Organizer    65.0
# 18         Japan             Calculator    15.0
# ...

# %%
# index location - iloc : to view a row at a specific index
df.iloc[0]

# to access specific entry of that row
df.iloc[1]["Country"]

# if we want to convert ouput to list view ---> imply wrap it in list()
# Out:
# 'Canada'

# %%
df[(df["Category"] == "Electronics") & (df["Country"] == "USA")]

# and if we add "USA", "Sweden" ---> gives eror, as python dont process the comma in here so we use .isin()
df[
    (df["Category"] == "Electronics") & 
    (df["Country"].isin(["USA", "Sweden"]))
]
# Out:
#     OrderID    CustomerName       Product     Category  Quantity   Price  \
# 0      1001      John Smith        Laptop  Electronics         1  1200.0
# 24     1025  Lucas Anderson  Tablet Stand  Electronics         1    28.0
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 24  2024-06-26     Yes  Sweden

# %%
df["Quantity"]
